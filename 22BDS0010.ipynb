# %% [markdown]
# <a href="https://colab.research.google.com/github/gautam-18/EDA/blob/main/22BDS0010.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/salemprakash/EDA/main/Data/wages.csv"
df = pd.read_csv(url)


df.info()
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6402 entries, 0 to 6401
# Data columns (total 16 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   rownames       6402 non-null   int64
#  1   id             6402 non-null   int64
#  2   lnw            6402 non-null   float64
#  3   exper          6402 non-null   float64
#  4   ged            6402 non-null   int64
#  5   postexp        6402 non-null   float64
#  6   black          6402 non-null   int64
#  7   hispanic       6402 non-null   int64
#  8   hgc            6402 non-null   int64
#  9   hgc.9          6402 non-null   int64
#  10  uerate         6402 non-null   float64
#  11  ue.7           6000 non-null   float64
#  12  ue.centert1    5996 non-null   float64
#  13  ue.mean        6402 non-null   float64
#  14  ue.person.cen  6402 non-null   float64
#  15  ue1            6402 non-null   float64
# dtypes: float64(9), int64(7)
# memory usage: 800.4 KB
#    rownames  id    lnw  exper  ged  postexp  black  hispanic  hgc  hgc.9  \
# 0         1  31  1.491  0.015    1    0.015      0         1    8     -1
# 1         2  31  1.433  0.715    1    0.715      0         1    8     -1
# 2         3  31  1.469  1.734    1    1.734      0         1    8     -1
# 3         4  31  1.749  2.773    1    2.773      0         1    8     -1
# 4         5  31  1.931  3.927    1    3.927      0         1    8     -1
#
#    uerate   ue.7  ue.centert1  ue.mean  ue.person.cen   ue1
# 0    3.21 -3.785         0.00     3.21           0.00  3.21
# 1    3.21 -3.785         0.00     3.21           0.00  3.21
# 2    3.21 -3.785         0.00     3.21           0.00  3.21
# 3    3.30 -3.705         0.08     3.21           0.08  3.21
# 4    2.89 -4.105        -0.32     3.21          -0.32  3.21

# %%
print("Shape of dataset:", df.shape)
# Out:
# Shape of dataset: (6402, 16)

# %%
print("\nSummary Statistics:\n", df.describe())
# Out:
# Summary Statistics:
#            rownames            id          lnw        exper          ged  \
# count  6402.000000   6402.000000  6402.000000  6402.000000  6402.000000
# mean   3201.500000   6300.923930     1.896686     3.957221     0.271946
# std    1848.242544   3548.319594     0.427669     2.797018     0.444997
# min       1.000000     31.000000     0.708000     0.001000     0.000000
# 25%    1601.250000   3194.000000     1.591000     1.609000     0.000000
# 50%    3201.500000   6582.000000     1.842000     3.451000     0.000000
# 75%    4801.750000   9300.000000     2.140000     5.949500     1.000000
# max    6402.000000  12543.000000     4.304000    12.700000     1.000000
#
#            postexp        black     hispanic          hgc        hgc.9  \
# count  6402.000000  6402.000000  6402.000000  6402.000000  6402.000000
# mean      0.907643     0.252890     0.241018     8.947516    -0.052484
# std       2.000627     0.434702     0.427735     1.347135     1.347135
# min       0.000000     0.000000     0.000000     6.000000    -3.000000
# 25%       0.000000     0.000000     0.000000     8.000000    -1.000000
# 50%       0.000000     0.000000     0.000000     9.000000     0.000000
# 75%       0.116750     1.000000     0.000000    10.000000     1.000000
# max      12.260000     1.000000     1.000000    12.000000     3.000000
#
#             uerate         ue.7  ue.centert1      ue.mean  ue.person.cen  \
# count  6402.000000  6000.000000  5996.000000  6402.000000    6402.000000
# mean      7.732980     0.729735    -1.015081     7.733727      -0.000011
# std       3.277642     3.278033     3.316673     2.460691       2.164534
# min       1.790000    -5.205000   -15.310000     2.890000      -8.403000
# 25%       5.390000    -1.605000    -2.900000     6.070000      -1.350500
# 50%       7.000000     0.000000    -0.500000     7.150000      -0.142000
# 75%       9.400000     2.300000     0.600000     8.650000       1.133000
# max      23.700000    16.705000    13.005000    17.130000      13.421000
#
#                ue1
# count  6402.000000
# mean      8.762088
# std       3.470540
# min       2.890000
# 25%       6.200000
# 50%       8.300000
# 75%      10.200000
# max      23.700000

# %%
#Transfromation Techniques

#Data Deduplication
print("Duplicate Rows Count:", df.duplicated().sum())
# Out:
# Duplicate Rows Count: 0

# %%
#Replacing Values if neg in experinece
df['exper'] = df['exper'].apply(lambda x: 0 if x < 0 else x)

# %%
#Check if there are any missing values in given dataset
print("Any Missing Values?", df.isnull().values.any())
# Out:
# Any Missing Values? True

# %%
#Count the missing values in the data set
print(df.isnull().sum())
# Out:
# rownames           0
# id                 0
# lnw                0
# exper              0
# ged                0
# postexp            0
# black              0
# hispanic           0
# hgc                0
# hgc.9              0
# uerate             0
# ue.7             402
# ue.centert1      406
# ue.mean            0
# ue.person.cen      0
# ue1                0
# dtype: int64

# %%
# Handling MissingData

#Visualising Missing Data Using Heatmap
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(8, 6))
sns.heatmap(df.isnull(), cmap="viridis", cbar=False, yticklabels=False)
plt.title("Missing Values Heatmap")
plt.show()

# %%
#Filling Missing Values
df['ue.centert1'] = df['ue.centert1'].fillna(df['ue.centert1'].mean())
df['ue.7'] = df['ue.7'].fillna(df['ue.7'].median())

print(df.isnull().sum())
# Out:
# rownames         0
# id               0
# lnw              0
# exper            0
# ged              0
# postexp          0
# black            0
# hispanic         0
# hgc              0
# hgc.9            0
# uerate           0
# ue.7             0
# ue.centert1      0
# ue.mean          0
# ue.person.cen    0
# ue1              0
# dtype: int64

# %%
df.isnull()
# Out:
#       rownames     id    lnw  exper    ged  postexp  black  hispanic    hgc  \
# 0        False  False  False  False  False    False  False     False  False
# 1        False  False  False  False  False    False  False     False  False
# 2        False  False  False  False  False    False  False     False  False
# 3        False  False  False  False  False    False  False     False  False
# 4        False  False  False  False  False    False  False     False  False
# ...        ...    ...    ...    ...    ...      ...    ...       ...    ...
# 6397     False  False  False  False  False    False  False     False  False
# 6398     False  False  False  False  False    False  False     False  False
# 6399     False  False  False  False  False    False  False     False  False
# 6400     False  False  False  False  False    False  False     False  False
# 6401     False  False  False  False  False    False  False     False  False
#
#       hgc.9  uerate   ue.7  ue.centert1  ue.mean  ue.person.cen    ue1
# 0     False   False  False        False    False          False  False
# 1     False   False  False        False    False          False  False
# 2     False   False  False        False    False          False  False
# 3     False   False  False        False    False          False  False
# 4     False   False  False        False    False          False  False
# ...     ...     ...    ...          ...      ...            ...    ...
# 6397  False   False  False        False    False          False  False
# 6398  False   False  False        False    False          False  False
# 6399  False   False  False        False    False          False  False
# 6400  False   False  False        False    False          False  False
# 6401  False   False  False        False    False          False  False
#
# [6402 rows x 16 columns]

# %%
#Discretization and binning

# Binning the 'lnw' column into 3 equal-width categories
df['lnw_bins'] = pd.cut(df['lnw'], bins=3, labels=['Low', 'Medium', 'High'])

# Check the resulting bins
print(df[['lnw', 'lnw_bins']].head())
# Out:
#      lnw lnw_bins
# 0  1.491      Low
# 1  1.433      Low
# 2  1.469      Low
# 3  1.749      Low
# 4  1.931   Medium

# %%
# Binning the 'exper' column into 4 equal-frequency categories
df['exper_bins'] = pd.qcut(df['exper'], q=4, labels=['Very Low', 'Low', 'Medium', 'High'])

# Check the resulting bins
print(df[['exper', 'exper_bins']].head())
# Out:
#    exper exper_bins
# 0  0.015   Very Low
# 1  0.715   Very Low
# 2  1.734        Low
# 3  2.773        Low
# 4  3.927     Medium

# %%
bin_edges = [0, 2, 2.5, 3, 3.25, 3.5]
bin_labels = ['Very Low', 'Low', 'Medium', 'High', 'Very High']

df['uerate_bins'] = pd.cut(df['uerate'], bins=bin_edges, labels=bin_labels)


print(df[['uerate', 'uerate_bins']].head())
# Out:
#    uerate uerate_bins
# 0    3.21        High
# 1    3.21        High
# 2    3.21        High
# 3    3.30   Very High
# 4    2.89      Medium

# %%
print(df['lnw_bins'].value_counts())
print(df['exper_bins'].value_counts())
print(df['uerate_bins'].value_counts())
# Out:
# lnw_bins
# Low       3619
# Medium    2708
# High        75
# Name: count, dtype: int64
# exper_bins
# Very Low    1601
# Low         1601
# High        1601
# Medium      1599
# Name: count, dtype: int64
# uerate_bins
# Very High    80
# Medium       78
# High         34
# Low          12
# Very Low      1
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt


df['lnw_bins'].value_counts().plot(kind='bar')
plt.title('Binned lnw Data')
plt.xlabel('Bins')
plt.ylabel('Count')
plt.show()

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt


columns_to_check = ['lnw', 'exper', 'ged', 'postexp', 'hgc', 'uerate']

# Plotting boxplots before removing outliers
plt.figure(figsize=(14, 6))
for i, column in enumerate(columns_to_check):
    plt.subplot(1, len(columns_to_check), i + 1)
    sns.boxplot(data=df, y=column)
    plt.title(f"Before - {column}")
plt.tight_layout()
plt.show()

# Outlier removal using IQR
df_cleaned = df.copy()
for column in columns_to_check:
    Q1 = df[column].quantile(0.25)
    Q3 = df[column].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    df_cleaned = df_cleaned[(df_cleaned[column] >= lower_bound) & (df_cleaned[column] <= upper_bound)]

# Plotting boxplots after removing outliers
plt.figure(figsize=(14, 6))
for i, column in enumerate(columns_to_check):
    plt.subplot(1, len(columns_to_check), i + 1)
    sns.boxplot(data=df_cleaned, y=column)
    plt.title(f"After - {column}")
plt.tight_layout()
plt.show()

print(f"Original dataset shape: {df.shape}")
print(f"Cleaned dataset shape: {df_cleaned.shape}")
# Out:
# Original dataset shape: (6255, 20)
# Cleaned dataset shape: (4492, 20)

# %% [markdown]
# # **Univariate analysis**

# %%
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
print(df.head(3))
print(df.tail(3))
# Out:
#    rownames  id    lnw  exper  ged  postexp  black  hispanic  hgc  hgc.9  \
# 0         1  31  1.491  0.015    1    0.015      0         1    8     -1
# 1         2  31  1.433  0.715    1    0.715      0         1    8     -1
# 2         3  31  1.469  1.734    1    1.734      0         1    8     -1
#
#    uerate   ue.7  ue.centert1  ue.mean  ue.person.cen   ue1 lnw_bins  \
# 0    3.21 -3.785          0.0     3.21            0.0  3.21      Low
# 1    3.21 -3.785          0.0     3.21            0.0  3.21      Low
# 2    3.21 -3.785          0.0     3.21            0.0  3.21      Low
#
#   exper_bins uerate_bins  lnw_zscore
# 0   Very Low        High   -0.948671
# 1   Very Low        High   -1.084300
# 2        Low        High   -1.000116
#       rownames     id    lnw  exper  ged  postexp  black  hispanic  hgc  \
# 6399      6400  12543  1.307  5.020    0      0.0      0         0    8
# 6400      6401  12543  1.842  5.681    0      0.0      0         0    8
# 6401      6402  12543  1.658  6.700    0      0.0      0         0    8
#
#       hgc.9  uerate  ue.7  ue.centert1  ue.mean  ue.person.cen  ue1 lnw_bins  \
# 6399     -1     8.8   1.8         -0.2     8.85          -0.05  9.0      Low
# 6400     -1     7.3   0.3         -1.7     8.85          -1.55  9.0      Low
# 6401     -1     7.7   0.7         -1.3     8.85          -1.15  9.0      Low
#
#      exper_bins uerate_bins  lnw_zscore
# 6399     Medium         NaN   -1.378943
# 6400     Medium         NaN   -0.127879
# 6401       High         NaN   -0.558152

# %%
df.dtypes
# Out:
# rownames            int64
# id                  int64
# lnw               float64
# exper             float64
# ged                 int64
# postexp           float64
# black               int64
# hispanic            int64
# hgc                 int64
# hgc.9               int64
# uerate            float64
# ue.7              float64
# ue.centert1       float64
# ue.mean           float64
# ue.person.cen     float64
# ue1               float64
# lnw_bins         category
# exper_bins       category
# uerate_bins      category
# lnw_zscore        float64
# dtype: object

# %%
print(df.describe())
pd.isna(df).any()
# Out:
#           rownames            id          lnw        exper          ged  \
# count  6255.000000   6255.000000  6255.000000  6255.000000  6255.000000
# mean   3208.651159   6314.783213     1.871272     3.931753     0.268425
# std    1851.310250   3554.003978     0.381149     2.779410     0.443176
# min       1.000000     31.000000     0.780000     0.001000     0.000000
# 25%    1610.500000   3230.000000     1.586000     1.598500     0.000000
# 50%    3213.000000   6620.000000     1.833000     3.430000     0.000000
# 75%    4812.500000   9316.000000     2.121000     5.906000     1.000000
# max    6402.000000  12543.000000     2.931000    12.260000     1.000000
#
#            postexp        black     hispanic          hgc        hgc.9  \
# count  6255.000000  6255.000000  6255.000000  6255.000000  6255.000000
# mean      0.890329     0.253717     0.239968     8.940368    -0.059632
# std       1.983010     0.435172     0.427098     1.343163     1.343163
# min       0.000000     0.000000     0.000000     6.000000    -3.000000
# 25%       0.000000     0.000000     0.000000     8.000000    -1.000000
# 50%       0.000000     0.000000     0.000000     9.000000     0.000000
# 75%       0.032000     1.000000     0.000000    10.000000     1.000000
# max      12.260000     1.000000     1.000000    12.000000     3.000000
#
#             uerate         ue.7  ue.centert1      ue.mean  ue.person.cen  \
# count  6255.000000  6255.000000  6255.000000  6255.000000    6255.000000
# mean      7.740868     0.693321    -1.003304     7.735217       0.006381
# std       3.272688     3.175433     3.205985     2.456322       2.167131
# min       1.790000    -5.205000   -15.310000     2.890000      -8.403000
# 25%       5.390000    -1.505000    -2.700000     6.070000      -1.348500
# 50%       7.000000     0.000000    -0.900000     7.150000      -0.126000
# 75%       9.400000     2.200000     0.400000     8.650000       1.140500
# max      23.700000    16.705000    13.005000    17.130000      13.421000
#
#                ue1   lnw_zscore
# count  6255.000000  6255.000000
# mean      8.760003    -0.059427
# std       3.467158     0.891292
# min       2.890000    -2.611300
# 25%       6.200000    -0.726519
# 50%       8.300000    -0.148925
# 75%      10.200000     0.524545
# max      23.700000     2.418679
# rownames         False
# id               False
# lnw              False
# exper            False
# ged              False
# postexp          False
# black            False
# hispanic         False
# hgc              False
# hgc.9            False
# uerate           False
# ue.7             False
# ue.centert1      False
# ue.mean          False
# ue.person.cen    False
# ue1              False
# lnw_bins         False
# exper_bins       False
# uerate_bins       True
# lnw_zscore       False
# dtype: bool

# %%
# Univariate Analysis for 'lnw'
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.hist(df['lnw'], bins=30, color='skyblue', edgecolor='black')
plt.title('Histogram of lnw')

plt.subplot(1, 2, 2)
sns.kdeplot(df['lnw'], shade=True, color='orange')
plt.title('Density Plot of lnw')
plt.show()

# Boxplot for 'lnw'
plt.figure(figsize=(6, 4))
sns.boxplot(y=df['lnw'], color='lightcoral')
plt.title('Boxplot of lnw')
plt.show()
# Out:
# <ipython-input-48-28557636cc93>:8: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(df['lnw'], shade=True, color='orange')

# %%
import matplotlib.pyplot as plt
import seaborn as sns


numerical_columns = ['exper', 'ged', 'postexp', 'hgc', 'uerate']


plt.figure(figsize=(15, 20))


plt.subplot(5, 2, 1)
plt.hist(df['exper'], bins=30, color='skyblue', edgecolor='black')
plt.title('Histogram of exper')
plt.subplot(5, 2, 2)
sns.kdeplot(df['exper'], fill=True, color='orange')
plt.title('Density Plot of exper')


plt.subplot(5, 2, 3)
plt.hist(df['ged'], bins=30, color='skyblue', edgecolor='black')
plt.title('Histogram of ged')
plt.subplot(5, 2, 4)
sns.kdeplot(df['ged'], fill=True, color='orange')
plt.title('Density Plot of ged')


plt.subplot(5, 2, 5)
plt.hist(df['postexp'], bins=30, color='skyblue', edgecolor='black')
plt.title('Histogram of postexp')
plt.subplot(5, 2, 6)
sns.kdeplot(df['postexp'], fill=True, color='orange')
plt.title('Density Plot of postexp')


plt.subplot(5, 2, 7)
plt.hist(df['hgc'], bins=30, color='skyblue', edgecolor='black')
plt.title('Histogram of hgc')
plt.subplot(5, 2, 8)
sns.kdeplot(df['hgc'], fill=True, color='orange')
plt.title('Density Plot of hgc')

plt.subplot(5, 2, 9)
plt.hist(df['uerate'], bins=30, color='skyblue', edgecolor='black')
plt.title('Histogram of uerate')
plt.subplot(5, 2, 10)
sns.kdeplot(df['uerate'], fill=True, color='orange')
plt.title('Density Plot of uerate')

plt.tight_layout()
plt.show()

# %% [markdown]
# # **Bivariate Analysis**

# %%
# Scatter plot for 'lnw' vs 'exper'
plt.figure(figsize=(6, 4))
sns.scatterplot(x=df['lnw'], y=df['exper'], color='teal')
plt.title('Scatter Plot: lnw vs exper')
plt.xlabel('lnw')
plt.ylabel('exper')
plt.show()

# Scatter plot for 'ged' vs 'postexp'
plt.figure(figsize=(6, 4))
sns.scatterplot(x=df['ged'], y=df['postexp'], color='teal')
plt.title('Scatter Plot: ged vs postexp')
plt.xlabel('ged')
plt.ylabel('postexp')
plt.show()

# %%
plt.figure(figsize=(6, 4))
sns.boxplot(x=df['black'], y=df['lnw'], palette='Set2')
plt.title('Boxplot: lnw vs black')
plt.xlabel('black')
plt.ylabel('lnw')
plt.show()


plt.figure(figsize=(6, 4))
sns.boxplot(x=df['hispanic'], y=df['uerate'], palette='Set3')
plt.title('Boxplot: uerate vs hispanic')
plt.xlabel('hispanic')
plt.ylabel('uerate')
plt.show()
# Out:
# <ipython-input-52-510ac5873bc3>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x=df['black'], y=df['lnw'], palette='Set2')
# <ipython-input-52-510ac5873bc3>:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x=df['hispanic'], y=df['uerate'], palette='Set3')

# %% [markdown]
# # Multivariate Analysis

# %%
sns.pairplot(df[['lnw', 'exper', 'ged', 'postexp', 'hgc', 'uerate']], diag_kind='kde', plot_kws={'alpha': 0.6})
plt.suptitle('Pairplot for Numerical Variables', y=1.02)
plt.show()

# %%
plt.figure(figsize=(10, 6))
correlation_matrix = df[['lnw', 'exper', 'ged', 'postexp', 'hgc', 'uerate']].corr()
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Correlation Heatmap')
plt.show()
